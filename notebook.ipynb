# %% [markdown]
# # Sample Notebook
#
# This is a sample Jupyter notebook for the claude_test project.

# %%
# Import the main module
from main import greet

# Test the greet function
print(greet("Jupyter"))

# %%
# New print function added
def show_status():
    print("Notebook is running!")
    print("Changes have been made!")

show_status()

# Simple demonstration
for i in range(5):
    print(f"Count: {i}")
